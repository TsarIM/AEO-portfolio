# %% [markdown]
# <a href="https://colab.research.google.com/github/TsarIM/AEO-portfolio/blob/main/ABC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from scipy.io import loadmat
import matplotlib.pyplot as plt

# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-c0bceae6-b886-45fb-b583-732b377e7388" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c0bceae6-b886-45fb-b583-732b377e7388">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = loadmat('BSE30.mat')

# %%
print(data.keys())
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'ExpReturn', 'ExpCovariance'])

# %%
expr=data['ExpReturn']
expcov=data['ExpCovariance']

# %%
df=pd.DataFrame(expr)
df.to_csv()
display(df)
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.012578  0.001214 -0.001786  0.022808  0.019224  0.007175 -0.007375
#
#          7         8         9   ...        20        21        22        23  \
# 0 -0.002025  0.019277  0.006248  ...  0.006233  0.000772  0.005212  0.014637
#
#          24        25        26        27        28        29
# 0 -0.003155  0.002344 -0.004736  0.003221  0.018308  0.004625
#
# [1 rows x 30 columns]

# %%
df2=pd.DataFrame(expcov)
df2.to_csv()
display(df2)
# Out:
#           0         1         2         3         4         5         6   \
# 0   0.007644  0.003317  0.001365  0.003941  0.003159  0.000741 -0.000528
# 1   0.003317  0.022309  0.004118  0.005824  0.003941  0.001252  0.000950
# 2   0.001365  0.004118  0.006683  0.005784  0.005398  0.002496  0.002348
# 3   0.003941  0.005824  0.005784  0.024482  0.012536  0.005233  0.002603
# 4   0.003159  0.003941  0.005398  0.012536  0.016375  0.004576  0.002624
# 5   0.000741  0.001252  0.002496  0.005233  0.004576  0.007268  0.000220
# 6  -0.000528  0.000950  0.002348  0.002603  0.002624  0.000220  0.011844
# 7   0.001616  0.008155  0.001857  0.002554  0.002362  0.000791  0.000880
# 8   0.000803 -0.003320  0.001024  0.003552  0.002134  0.001724  0.001752
# 9   0.002151  0.006686  0.002569  0.004446  0.003095  0.001360  0.000965
# 10  0.002739  0.013678  0.003055  0.004528  0.002280  0.002081  0.000371
# 11  0.000912  0.004269  0.001300  0.001863  0.001282  0.000635  0.001721
# ...

# %%
Returns=df
covariance=df2

# %%
def softmax(x):
    e_x = np.exp(x - np.max(x))
    return e_x / e_x.sum(axis=0)

# %%
def sharpeRatio(Returns,covariance,unscaled_weights):

  weights=softmax(unscaled_weights)
  P_return=np.sum((Returns.mean()*weights))

  P_risk=np.sqrt(np.dot(weights.T,np.dot(covariance,weights)))

  return -P_return/P_risk

# %%
def roulette_wheel_selection(P):
    r = np.random.rand()
    C = np.cumsum(P)
    i = np.argmax(r <= C)  # Find the first index where r <= C
    return i

# %%
def find_AR_i(Returns,covariance,weights):
  P_risk=np.sqrt(np.dot(weights.T,np.dot(covariance,weights)))
  MR=np.dot(covariance,weights)/P_risk
  AR=weights*MR
  return AR

def Risk_Budgeting_constraint(Returns,covariance,AR,weights):
  P_risk=np.sqrt(np.dot(weights.T,np.dot(covariance,weights)))
  dim=len(weights)
  for i in range(dim):
    if AR[i]>0.125*P_risk:
      return False
  return True

# %%
def ABC(Returns,covariance,n_iters,n_popn):

  dim=len(Returns.columns)
  n_onlookers=n_popn
  L=np.round(0.6*dim*n_popn)#Abandonment Limit Parameter (Trial Limit)
  a=1  #Acceleration Coefficient Upper Bound

  individuals=np.zeros((n_popn,dim))
  fitness=np.zeros(n_popn)

  for i in range(n_popn):
    individuals[i,:]=np.random.rand(1,dim)
    fitness[i]=sharpeRatio(Returns,covariance,individuals[i,:])

  indF = np.argsort(fitness)[::-1]
  individuals = individuals[indF, :]
  fitness = fitness[indF]

  BestF = fitness[-1]
  BestX = individuals[-1, :]

  C=np.zeros((n_popn,1))#Abandonment Counter

  new_indi=np.zeros((n_popn,dim))

  history=[]

  for it in range(n_iters):

    #Recruited bees
    for i in range(n_popn):

      # Choose k randomly, not equal to i
      K = list(range(0,i))+list(range(i + 1,n_popn))
      k = np.random.choice(K)

      # Define Acceleration Coeff.
      phi = a * np.random.uniform(-1, 1,dim)

      new_indi[i,:]=individuals[i,:]+phi*(individuals[i,:]-individuals[k,:])

      new_fit=sharpeRatio(Returns,covariance,new_indi[i,:])

      if new_fit<fitness[i]:
        individuals[i,:]=new_indi[i,:]
        fitness[i]=new_fit
      else:
        C[i]=C[i]+1

    #Calculate Fitness Values and Selection Probabilities
    meancost=np.mean(fitness)
    F=np.zeros(n_popn)
    for i in range(n_popn):
      F[i]=np.exp(-fitness[i]/meancost)
    P=F/np.sum(F)

    #Onlooker bees
    for m in range(n_onlookers):

      i=roulette_wheel_selection(P)

      # Choose k randomly, not equal to i
      K = list(range(0,i))+list(range(i + 1,n_popn))
      k = np.random.choice(K)

      # Define Acceleration Coeff.
      phi = a * np.random.uniform(-1, 1,dim)

      new_indi[i,:]=individuals[i,:]+phi*(individuals[i,:]-individuals[k,:])

      new_fit=sharpeRatio(Returns,covariance,new_indi[i,:])

      if new_fit<fitness[i]:
        individuals[i,:]=new_indi[i,:]
        fitness[i]=new_fit
      else:
        C[i]=C[i]+1

    #Scout Bees
    for i in range(n_popn):
      if C[i]>=L:
        individuals[i,:]=np.random.uniform(0,1,dim)
        fitness[i]=sharpeRatio(Returns,covariance,individuals[i,:])
        C[i]=0

    indF = np.argsort(fitness)[::-1]
    individuals = individuals[indF,:]
    fitness = fitness[indF]

    BestF = fitness[-1]
    BestX = individuals[-1,:]
    print(softmax(BestX))
    print(-BestF)
    history.append(-BestF)

  return history,softmax(BestX),-BestF

# %%
history,BestX,Sharpe=ABC(Returns,covariance,100,100)
# Out:
# [0.02375435 0.01956016 0.02270126 0.01886172 0.02922892 0.02048549
#  0.0385973  0.02740529 0.02216191 0.08566467 0.03127492 0.02514896
#  0.01927493 0.02170944 0.0042502  0.01334336 0.0234722  0.01779146
#  0.01924901 0.30979389 0.02356509 0.01027909 0.01305254 0.02054564
#  0.02194003 0.03005977 0.01052352 0.02957223 0.03355922 0.01317342]
# 0.15912908357050354
# [0.00907467 0.00728948 0.0147532  0.00668566 0.01092055 0.00852018
#  0.02621335 0.00759616 0.0069383  0.07151862 0.01459002 0.01074744
#  0.00631815 0.00800979 0.00151942 0.01052273 0.00914318 0.00561789
#  0.00857469 0.66198679 0.00542538 0.00382408 0.00804396 0.00683187
#  0.00817802 0.01516351 0.00422212 0.01383208 0.0229075  0.0050312 ]
# 0.26882096842896686
# [0.00907467 0.00728948 0.0147532  0.00668566 0.01092055 0.00852018
#  0.02621335 0.00759616 0.0069383  0.07151862 0.01459002 0.01074744
#  0.00631815 0.00800979 0.00151942 0.01052273 0.00914318 0.00561789
# ...

# %%
print(history)
# Out:
# [0.15570091858628396, 0.2550344161320503, 0.2837940040197819, 0.32214355839158537, 0.32214355839158537, 0.3737740046758769, 0.3737740046758769, 0.3737740046758769, 0.3737740046758769, 0.3737740046758769, 0.3737740046758769, 0.3737740046758769, 0.3737740046758769, 0.3737740046758769, 0.3737740046758769, 0.3737740046758769, 0.3737740046758769, 0.3737740046758769, 0.3737740046758769, 0.3737740046758769, 0.3737740046758769, 0.3737740046758769, 0.3737740046758769, 0.3737740046758769, 0.3737740046758769, 0.37539416510819545, 0.37539416510819545, 0.37539416510819545, 0.37539416510819545, 0.3766010613592324, 0.3766010613592324, 0.38427324477677127, 0.38427324477677127, 0.38427324477677127, 0.38427324477677127, 0.38427324477677127, 0.38699221748171164, 0.38699221748171164, 0.38699221748171164, 0.38699221748171164, 0.38699221748171164, 0.38699221748171164, 0.38699221748171164, 0.38699221748171164, 0.38699221748171164, 0.38699221748171164, 0.38699221748171164, 0.38699221748171164, 0.38699221748
# ...

# %%
# Number of iterations
iterations = range(1, len(history) + 1)

# Plotting the convergence graph
plt.figure(figsize=(10, 6))
plt.plot(iterations, history, marker='D', linestyle='-', color='r',markerfacecolor='none', markeredgecolor='r')

plt.title('Convergence - Artificial BEE Colony')
plt.xlabel('Number of Iterations')
plt.ylabel('Sharpe Ratio')

plt.grid(True)

# Showing the plot
plt.show()

# %%
def spaceBound(x,lb,ub):
  for i in range(len(x)):
    if x[i]<lb[i] or x[i]>ub[i]:
      x[i]=np.random.uniform(lb[i],ub[i])
  return x

# %%
def AEO(Returns,covariance,n_iters,n_popn):
  #initialise an ecosystem, population of potential solutions

  dim=len(Returns.columns)

  lb=np.full(dim,0.00001) #lower bound
  ub=np.full(dim,1000) #upper bound

  #constraints add krna bacha hai

  #for each individual calculate fitness and store in array
  individuals=np.zeros((n_popn,dim))
  fitness=np.zeros(n_popn)


  for i in range(n_popn):

    individuals[i,:]=np.random.rand(1,dim)*(ub-lb)+lb

    fitness[i]=sharpeRatio(Returns,covariance,individuals[i,:])

  #sort fitness in increasing order of sharpe ratio and get the indexes
  indF = np.argsort(fitness)[::-1]

  # Reorder PopPos and PopFit based on sorted indices
  individuals = individuals[indF, :]
  fitness = fitness[indF]

  # Select the best fitness and corresponding position
  BestF = fitness[-1]
  BestX = individuals[-1, :]

  #n_iters for loop

  new_indi=np.zeros((n_popn,dim))

#loop1
  history_aeo=[]
  for it in range(n_iters):

    #production
    r1=np.random.rand()
    a=(1-it/n_iters)*r1
    xrand = np.random.rand(dim)*(ub-lb)+lb
    new_indi[0,:]=(1-a)*individuals[n_popn-1,:]+a*xrand #eq 1

    #first herbivore
    u = np.random.randn(1,dim)
    v = np.random.randn(1,dim)
    # Compute C based on the given equation
    C = 0.5 * u / np.abs(v)
    # Update new_indi based on the given equation
    new_indi[1,:] = individuals[1,:]+C*(individuals[1,:]-new_indi[0,:]) #eq 6

#loop2
    for i in range (2,n_popn):

      u = np.random.randn(1,dim)
      v = np.random.randn(1,dim)
      C = 0.5 * u / np.abs(v)#consumption factor
      r=np.random.rand()

      if r<1/3:
        new_indi[i,:] = individuals[i,:]+C*(individuals[i,:]-new_indi[0,:]) #eq 6

      elif r>2/3:
        r2 = np.random.rand()
        rand_idx = np.random.randint(1,i)# [1,i)
        new_indi[i,:] = individuals[i,:]+C*(r2*(individuals[i,:]-new_indi[0,:])+(1-r2)*(individuals[i,:]-individuals[rand_idx,:])) #eq 8

      else:
        rand_idx2 = np.random.randint(1,i)
        new_indi[i,:] = individuals[i,:]+C*(individuals[i,:]-individuals[rand_idx2,:]) #eq 7
#loop2 end

      new_fit=np.zeros(n_popn)
#loop3
    for i in range(n_popn):
      new_indi[i,:] = spaceBound(new_indi[i,:],lb,ub)
      new_fit[i] = sharpeRatio(Returns,covariance,new_indi[i,:])

      if new_fit[i]<fitness[i]:
        fitness[i]=new_fit[i]
        individuals[i,:]=new_indi[i,:]
#loop3 end

    mini = np.argmin(fitness)
#loop4
    for i in range(n_popn):
      r3 = np.random.rand()
      index = np.round(np.random.rand())+1
      D = 3*np.random.randn(1,dim)
      e = r3*(np.random.randint(1,3))-1
      h =2*r3-1
      new_indi[i,:] = individuals[mini,:]+D*(e*individuals[mini,:]-h*individuals[i,:]) #eq 9
#loop4 end

#loop5
    for i in range(n_popn):
      new_indi[i,:] = spaceBound(new_indi[i,:],lb,ub)
      new_fit[i] = sharpeRatio(Returns,covariance,new_indi[i,:])

      if new_fit[i]<fitness[i]:
        fitness[i]=new_fit[i]
        individuals[i,:]=new_indi[i,:]
#loop5 end

    indF = np.argsort(fitness)[::-1]
    individuals = individuals[indF, :]
    fitness = fitness[indF]

    if fitness[-1]<BestF:
      BestF = fitness[-1]
      BestX = individuals[-1, :]

    print(softmax(BestX),-BestF)
    history_aeo.append(-BestF)

  return history_aeo,softmax(BestX),-BestF

# %%
history_aeo,BestX_aeo,sharpe_aeo=AEO(Returns,covariance,100,100)
# Out:
# [1.99673003e-001 1.97947037e-150 5.56951089e-176 3.88477756e-149
#  2.29374602e-304 2.27718850e-226 1.07154245e-124 1.81780845e-202
#  7.96465442e-001 9.58168486e-202 2.54854061e-269 2.66453079e-138
#  7.81920350e-137 1.93031567e-125 3.37131975e-007 0.00000000e+000
#  1.93898339e-259 1.49543208e-203 8.16824936e-011 3.10750004e-168
#  1.12118943e-290 5.12900305e-057 2.64151344e-201 1.93637427e-046
#  6.38501700e-252 3.86121784e-003 3.08863270e-222 3.83893577e-156
#  9.76727861e-151 3.79095377e-038] 0.29849851010887246
# [1.99673003e-001 1.97947037e-150 5.56951089e-176 3.88477756e-149
#  2.29374602e-304 2.27718850e-226 1.07154245e-124 1.81780845e-202
#  7.96465442e-001 9.58168486e-202 2.54854061e-269 2.66453079e-138
#  7.81920350e-137 1.93031567e-125 3.37131975e-007 0.00000000e+000
#  1.93898339e-259 1.49543208e-203 8.16824936e-011 3.10750004e-168
#  1.12118943e-290 5.12900305e-057 2.64151344e-201 1.93637427e-046
#  6.38501700e-252 3.86121784e-003 3.08863270e-222 3.83893577e-156
# ...

# %%
iterations = range(1, len(history) + 1)

plt.figure(figsize=(10, 6))

plt.plot(iterations, history, marker='D', linestyle='-', color='b',
         markerfacecolor='none', markeredgecolor='b', label='ABC')

plt.plot(iterations, history_aeo, marker='o', linestyle='-', color='r',
         markerfacecolor='none', markeredgecolor='r', label='AEO')

plt.title('Convergence Comparision')
plt.xlabel('Number of Iterations')
plt.ylabel('Sharpe Ratio')

plt.legend()

plt.grid(True)

plt.show()

# %%
print(history_aeo)
# Out:
# [0.29849851010887246, 0.29849851010887246, 0.2992599551313854, 0.2992599551313854, 0.2994520481281664, 0.2994520481281664, 0.2994520481281664, 0.2994520481281664, 0.2994520481281664, 0